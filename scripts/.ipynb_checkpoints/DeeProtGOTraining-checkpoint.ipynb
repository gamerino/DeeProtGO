# %% [markdown]
# # Training a DeeProtGO model

# %% [markdown]
# This notebook is aimed to train DeeProtGO to predict Bilogical Process (BP) Gene Ontology (GO) terms for *NK* proteins from Eukarya organisms.

# %% [markdown]
# ## Requirements

# %%
import os
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
#from google.colab import drive

# %%
# drive.mount('/content/drive')

# %%
os.chdir('/home/gabriela/Insync/gmerino@sinc.unl.edu.ar/Google Drive/EBI-EMBL/GOAnnot/DeeProtGO/')

# %%
from src2.sampler import Sampler
from src2.dataloader import Dataloader
from src2.DNNModel import DNNModel
from src2.logger import Logger
from src2.DNN import DNN
from src2.earlyStop import EarlyStopping

# %% [markdown]
# ### 1. Setting global parameters

# %%
torch.set_num_threads(torch.get_num_threads())
use_GPU = True
if use_GPU & torch.cuda.is_available():
    torch.cuda.manual_seed_all(1)
else:
    use_GPU = False
np.random.seed(1)
torch.manual_seed(1)

# %%
# Directory for saving model fitting results 
trainingDate = '26032021'
res_dir = "examples/train_NK_EUKA_BP/"
if not os.path.isdir('./'+res_dir):
    os.mkdir(res_dir)

# %% [markdown]
# ### 2.  Setup parameters and model hyperparameters

# %%
Nfolds = 3
activFunc = F.elu
optimMethod = torch.optim.Adam
criterion = nn.BCELoss
thresh = 0.2
learning_rate = 0.005
nepoch = 100
patience = 10
nbatch = 128
pDrop = 0.5

pPSD1 = 0.5
pPSD2 = 0.35
pEmb1 = 0.7
pEmb2 = 0.5
pTaxon1 = 0.7
pTaxon2 = 0.5

pHidden1 = 1
pHidden2 = 0.7

samplingNegPerc = 0.1399 # Of all negatives, we want to take 0.1399*100 of the data

# %% [markdown]
# ### 3. Data loading

# %%
dirData = 'data/processed/Training/'
propOutFile = dirData + "GOTermsPropRel_Euka_BP_train.tab" # file with relationships between GO terms

# %%
dloaderAll = Dataloader(dirData = dirData, posEntriesFile = "PosEntries_Euka_BP.tab",
                        negEntriesFile = "NegEntries_Euka_BP.tab",
                        netOutPath = "netOut_BP_Euka.h5", PSDPath = "LevSim_BP_Euka.h5", 
                        EmbPath = "Emb_BP_Euka.h5", 
                        TaxonPath = "Taxon_BP_Euka.h5", samplingNegPerc = samplingNegPerc)
# Out:
# Loading data...
# Dataset ready with 7180 cases .

# %%
case = "PSD_Emb_Taxon"
cases = dloaderAll.get_labels()

# %% [markdown]
# ### 4. Model training

# %%
sampler_list = []
for fold in range(Nfolds):
    sampler_list.append(Sampler(cases, fold, Nfolds, nbatch, partsize=[.70, .10, .20]))
loggerTrain = Logger(res_dir)
loggerTrain.start("train_%s" % (trainingDate))
loggerValid = Logger(res_dir)
loggerValid.start("valid_%s" % (trainingDate))
loggerTest = Logger(res_dir)
loggerTest.start("test_%s" % (trainingDate))
loggerTest.log("fold\tF1CAFA\tpreCAFA\trecCAFA\tthresh\tF1\tpre\trec\n")
# Out:
# fold	F1CAFA	preCAFA	recCAFA	thresh	F1	pre	rec

# %%
for fold in range(Nfolds):
    early_stopping = EarlyStopping(patience = patience, verbose = True, res_dir = res_dir,
                                   modelName = case)
    loggerTrain.log("epoch\tloss\n")
    loggerValid.log("epoch\tloss\tF1\tpre\trec\n")
    trainingSampler = sampler_list[fold].batch_ind("train")
    total_batch_train = len(trainingSampler)
    validSampler = sampler_list[fold].batch_ind("validation")
    total_batch_val = len(validSampler)
    testSampler = sampler_list[fold].batch_ind("test")
    N_in_1 = len(dloaderAll.get_PSD(cases[0]))
    N_in_2 = len(dloaderAll.get_Taxon(cases[0]))
    N_in_3 = len(dloaderAll.get_Emb(cases[0]))
    DeeProtGO_Euka_NK_BP = DNNModel(res_dir, propOutFile = propOutFile, nbatch = nbatch, N_in_1 = N_in_1,
                                    N_in_2 = N_in_2, N_in_3 = N_in_3, pN1_1 = pPSD1, pN1_2 = pPSD2,
                                    pN2_1 = pEmb1, pN2_2 = pEmb2, pN3_1 = pTaxon1, pN3_2 = pTaxon2,
                                    pNO_1 = pHidden1, pNO_2 = pHidden2, thresh = thresh, pDrop = pDrop,
                                    activFunc = activFunc, optimMethod = optimMethod,criterion = criterion,
                                    learning_rate = learning_rate, useGPU = use_GPU)
    epoch = 0
    while epoch < nepoch:
        train_loss=0
        for it in range(total_batch_train):
            inData1, inData2, inData3, _, _, _, outData = dloaderAll.get_batch(trainingSampler[it])
            loss, _ = DeeProtGO_Euka_NK_BP.train(outData, inData1, inData2, inData3)
            train_loss += loss
        msgA="%d\t%.6f\n" %(epoch, train_loss/total_batch_train)
        loggerTrain.log(msgA)
        # validation
        valid_loss = 0
        valid_f1 = 0
        valid_pre = 0
        valid_rec = 0
        for it in range(total_batch_val):
            inData1,inData2,inData3,_,_,_,outData = dloaderAll.get_batch(validSampler[it])
            loss, f1, pre, rec = DeeProtGO_Euka_NK_BP.test(outData, inData1,inData2, inData3, 
                                              CAFAerror = False)
            valid_loss += loss
            valid_f1 += f1
            valid_pre += pre
            valid_rec += rec
        valid_loss = valid_loss/total_batch_val
        valid_pre = valid_pre/total_batch_val
        valid_rec = valid_rec/total_batch_val
        valid_f1 = valid_f1/total_batch_val
        msg="%d\t%.5f\t%.3f\t%.3f\t%.3f\n" %(epoch,valid_loss, valid_f1, valid_pre, valid_rec)
        loggerValid.log(msg)
        early_stopping(valid_loss, DeeProtGO_Euka_NK_BP.net)
        if early_stopping.early_stop:
            print("Early stopping")
            break
        epoch+=1
    DeeProtGO_Euka_NK_BP.net.load_state_dict(torch.load(res_dir+case+'checkpoint.pt'))
    inData1,inData2,inData3,_,_,_,outData = dloaderAll.get_batch(testSampler[0])
    _, fCafa, preCafa, recCafa, thresh_A, test_f1, test_pre, test_rec = DeeProtGO_Euka_NK_BP.test(outData, inData1,
                                                                                                  inData2, inData3,
                                                                                                  CAFAerror = True,
                                                                                                  propPrediction = True)
    msg="%d\t%.3f\t%.3f\t%.3f\t%.3f\t%.3f\t%.3f\t%.3f\n" %(fold,fCafa, preCafa, recCafa, thresh_A,
                                                                test_f1, test_pre, test_rec)
    loggerTest.log(msg)
# Out:
# epoch	loss
# epoch	loss	F1	pre	rec
# 0	2.165125
# 0	1.11681	0.006	0.003	0.526
# Validation loss decreased (inf --> 1.116807).  Saving model ...
# 1	0.401084
# 1	0.19270	0.272	0.203	0.418
# Validation loss decreased (1.116807 --> 0.192700).  Saving model ...
# 2	0.204410
# 2	0.10673	0.340	0.283	0.429
# Validation loss decreased (0.192700 --> 0.106725).  Saving model ...
# 3	0.198276
# 3	0.11562	0.323	0.258	0.434
# EarlyStopping counter: 1 out of 10.000000
# 4	0.131033
# 4	0.08051	0.369	0.328	0.423
# Validation loss decreased (0.106725 --> 0.080513).  Saving model ...
# 5	0.089963
# 5	0.05742	0.353	0.291	0.449
# Validation loss decreased (0.080513 --> 0.057424).  Saving model ...
# 6	0.076800
# 6	0.05491	0.354	0.297	0.440
# Validation loss decreased (0.057424 --> 0.054908).  Saving model ...
# 7	0.061794
# 7	0.05016	0.380	0.340	0.432
# Validation loss decreased (0.054908 --> 0.050165).  Saving model ...
# 8	0.063115
# 8	0.04809	0.378	0.333	0.437
# Validation loss decreased (0.050165 --> 0.048093).  Saving model ...
# 9	0.055177
# 9	0.04434	0.393	0.356	0.440
# Validation loss decreased (0.048093 --> 0.044339).  Saving model ...
# 10	0.053089
# 10	0.04436	0.396	0.364	0.435
# EarlyStopping counter: 1 out of 10.000000
# 11	0.048450
# 11	0.04144	0.403	0.365	0.450
# Validation loss decreased (0.044339 --> 0.041443).  Saving model ...
# 12	0.046226
# 12	0.04138	0.392	0.344	0.456
# Validation loss decreased (0.041443 --> 0.041381).  Saving model ...
# 13	0.045174
# 13	0.04039	0.413	0.381	0.451
# Validation loss decreased (0.041381 --> 0.040389).  Saving model ...
# 14	0.044110
# 14	0.03963	0.413	0.376	0.459
# Validation loss decreased (0.040389 --> 0.039632).  Saving model ...
# 15	0.043508
# 15	0.03989	0.417	0.378	0.465
# EarlyStopping counter: 1 out of 10.000000
# 16	0.042885
# 16	0.03958	0.409	0.362	0.471
# Validation loss decreased (0.039632 --> 0.039579).  Saving model ...
# 17	0.042408
# 17	0.03924	0.414	0.370	0.469
# Validation loss decreased (0.039579 --> 0.039238).  Saving model ...
# 18	0.042304
# 18	0.03900	0.407	0.357	0.475
# Validation loss decreased (0.039238 --> 0.039004).  Saving model ...
# 19	0.041722
# 19	0.03917	0.412	0.362	0.479
# EarlyStopping counter: 1 out of 10.000000
# 20	0.041336
# 20	0.03872	0.407	0.355	0.477
# Validation loss decreased (0.039004 --> 0.038722).  Saving model ...
# 21	0.040931
# 21	0.03834	0.415	0.365	0.483
# Validation loss decreased (0.038722 --> 0.038343).  Saving model ...
# 22	0.040711
# 22	0.03819	0.413	0.364	0.479
# Validation loss decreased (0.038343 --> 0.038192).  Saving model ...
# 23	0.040799
# 23	0.03832	0.414	0.361	0.486
# EarlyStopping counter: 1 out of 10.000000
# 24	0.040522
# 24	0.03844	0.412	0.360	0.482
# EarlyStopping counter: 2 out of 10.000000
# 25	0.040560
# 25	0.03801	0.411	0.352	0.492
# Validation loss decreased (0.038192 --> 0.038013).  Saving model ...
# 26	0.040342
# 26	0.03799	0.410	0.353	0.488
# Validation loss decreased (0.038013 --> 0.037991).  Saving model ...
# 27	0.039737
# 27	0.03785	0.415	0.358	0.494
# Validation loss decreased (0.037991 --> 0.037855).  Saving model ...
# 28	0.039535
# 28	0.03795	0.414	0.360	0.487
# EarlyStopping counter: 1 out of 10.000000
# 29	0.039327
# 29	0.03777	0.421	0.370	0.487
# Validation loss decreased (0.037855 --> 0.037771).  Saving model ...
# 30	0.039323
# 30	0.03817	0.418	0.366	0.488
# EarlyStopping counter: 1 out of 10.000000
# 31	0.039028
# 31	0.03739	0.415	0.359	0.493
# Validation loss decreased (0.037771 --> 0.037386).  Saving model ...
# 32	0.038925
# 32	0.03780	0.412	0.354	0.493
# EarlyStopping counter: 1 out of 10.000000
# 33	0.039058
# 33	0.03772	0.412	0.355	0.493
# EarlyStopping counter: 2 out of 10.000000
# 34	0.039024
# 34	0.03758	0.424	0.376	0.487
# EarlyStopping counter: 3 out of 10.000000
# 35	0.038782
# 35	0.03776	0.420	0.368	0.490
# EarlyStopping counter: 4 out of 10.000000
# 36	0.038536
# 36	0.03781	0.415	0.359	0.495
# EarlyStopping counter: 5 out of 10.000000
# 37	0.038173
# 37	0.03728	0.411	0.351	0.498
# Validation loss decreased (0.037386 --> 0.037277).  Saving model ...
# 38	0.038091
# 38	0.03787	0.412	0.352	0.498
# EarlyStopping counter: 1 out of 10.000000
# 39	0.038222
# 39	0.03775	0.410	0.349	0.496
# EarlyStopping counter: 2 out of 10.000000
# 40	0.038244
# 40	0.03725	0.417	0.359	0.497
# Validation loss decreased (0.037277 --> 0.037247).  Saving model ...
# 41	0.037486
# 41	0.03796	0.424	0.376	0.488
# EarlyStopping counter: 1 out of 10.000000
# 42	0.037585
# 42	0.03797	0.408	0.345	0.500
# EarlyStopping counter: 2 out of 10.000000
# 43	0.037427
# 43	0.03787	0.407	0.344	0.500
# EarlyStopping counter: 3 out of 10.000000
# 44	0.037422
# 44	0.03752	0.415	0.355	0.501
# EarlyStopping counter: 4 out of 10.000000
# 45	0.037028
# 45	0.03804	0.412	0.350	0.500
# EarlyStopping counter: 5 out of 10.000000
# 46	0.036861
# 46	0.03782	0.414	0.355	0.499
# EarlyStopping counter: 6 out of 10.000000
# 47	0.037019
# 47	0.03796	0.428	0.377	0.497
# EarlyStopping counter: 7 out of 10.000000
# 48	0.036389
# 48	0.03813	0.427	0.376	0.495
# EarlyStopping counter: 8 out of 10.000000
# 49	0.036422
# 49	0.03821	0.422	0.369	0.494
# EarlyStopping counter: 9 out of 10.000000
# 50	0.036220
# 50	0.03813	0.424	0.372	0.494
# EarlyStopping counter: 10 out of 10.000000
# Early stopping
# 0	0.380	0.440	0.334	0.190	0.398	0.327	0.510
# epoch	loss
# epoch	loss	F1	pre	rec
# 0	2.544253
# 0	3.05596	0.006	0.003	0.499
# Validation loss decreased (inf --> 3.055965).  Saving model ...
# 1	0.901334
# 1	0.81899	0.150	0.091	0.439
# Validation loss decreased (3.055965 --> 0.818987).  Saving model ...
# 2	0.538094
# 2	0.26401	0.328	0.285	0.393
# Validation loss decreased (0.818987 --> 0.264006).  Saving model ...
# 3	0.268663
# 3	0.14269	0.354	0.324	0.395
# Validation loss decreased (0.264006 --> 0.142687).  Saving model ...
# 4	0.256760
# 4	0.24948	0.247	0.181	0.395
# EarlyStopping counter: 1 out of 10.000000
# 5	0.227131
# 5	0.14528	0.338	0.282	0.428
# EarlyStopping counter: 2 out of 10.000000
# 6	0.152325
# 6	0.09739	0.358	0.329	0.399
# Validation loss decreased (0.142687 --> 0.097393).  Saving model ...
# 7	0.098807
# 7	0.06738	0.359	0.332	0.397
# Validation loss decreased (0.097393 --> 0.067384).  Saving model ...
# 8	0.081493
# 8	0.06781	0.377	0.371	0.387
# EarlyStopping counter: 1 out of 10.000000
# 9	0.062002
# 9	0.05329	0.377	0.357	0.402
# Validation loss decreased (0.067384 --> 0.053288).  Saving model ...
# 10	0.055532
# 10	0.05140	0.382	0.360	0.412
# Validation loss decreased (0.053288 --> 0.051399).  Saving model ...
# 11	0.063993
# 11	0.06345	0.372	0.332	0.426
# EarlyStopping counter: 1 out of 10.000000
# 12	0.060057
# 12	0.05413	0.384	0.360	0.415
# EarlyStopping counter: 2 out of 10.000000
# 13	0.051467
# 13	0.04872	0.391	0.357	0.436
# Validation loss decreased (0.051399 --> 0.048724).  Saving model ...
# 14	0.047987
# 14	0.04733	0.396	0.369	0.431
# Validation loss decreased (0.048724 --> 0.047332).  Saving model ...
# 15	0.046774
# 15	0.04597	0.397	0.371	0.431
# Validation loss decreased (0.047332 --> 0.045970).  Saving model ...
# 16	0.046604
# 16	0.04557	0.396	0.363	0.439
# Validation loss decreased (0.045970 --> 0.045567).  Saving model ...
# 17	0.043409
# 17	0.04369	0.407	0.383	0.438
# Validation loss decreased (0.045567 --> 0.043686).  Saving model ...
# 18	0.042226
# 18	0.04337	0.406	0.375	0.445
# Validation loss decreased (0.043686 --> 0.043365).  Saving model ...
# 19	0.042150
# 19	0.04332	0.397	0.354	0.454
# Validation loss decreased (0.043365 --> 0.043315).  Saving model ...
# 20	0.041708
# 20	0.04320	0.402	0.371	0.442
# Validation loss decreased (0.043315 --> 0.043205).  Saving model ...
# 21	0.041030
# 21	0.04295	0.405	0.369	0.452
# Validation loss decreased (0.043205 --> 0.042948).  Saving model ...
# 22	0.040795
# 22	0.04256	0.400	0.354	0.463
# Validation loss decreased (0.042948 --> 0.042563).  Saving model ...
# 23	0.040855
# 23	0.04304	0.399	0.360	0.453
# EarlyStopping counter: 1 out of 10.000000
# 24	0.040443
# 24	0.04288	0.399	0.361	0.450
# EarlyStopping counter: 2 out of 10.000000
# 25	0.040414
# 25	0.04296	0.409	0.375	0.453
# EarlyStopping counter: 3 out of 10.000000
# 26	0.041664
# 26	0.04273	0.399	0.352	0.463
# EarlyStopping counter: 4 out of 10.000000
# 27	0.040042
# 27	0.04203	0.408	0.372	0.455
# Validation loss decreased (0.042563 --> 0.042030).  Saving model ...
# 28	0.039479
# 28	0.04264	0.406	0.368	0.457
# EarlyStopping counter: 1 out of 10.000000
# 29	0.039434
# 29	0.04233	0.403	0.357	0.466
# EarlyStopping counter: 2 out of 10.000000
# 30	0.039204
# 30	0.04212	0.401	0.360	0.459
# EarlyStopping counter: 3 out of 10.000000
# 31	0.038702
# 31	0.04198	0.400	0.352	0.468
# Validation loss decreased (0.042030 --> 0.041980).  Saving model ...
# 32	0.038895
# 32	0.04225	0.414	0.381	0.457
# EarlyStopping counter: 1 out of 10.000000
# 33	0.038607
# 33	0.04236	0.403	0.358	0.466
# EarlyStopping counter: 2 out of 10.000000
# 34	0.038315
# 34	0.04229	0.405	0.362	0.463
# EarlyStopping counter: 3 out of 10.000000
# 35	0.038172
# 35	0.04173	0.413	0.376	0.462
# Validation loss decreased (0.041980 --> 0.041732).  Saving model ...
# 36	0.038086
# 36	0.04191	0.403	0.357	0.467
# EarlyStopping counter: 1 out of 10.000000
# 37	0.037847
# 37	0.04247	0.403	0.363	0.457
# EarlyStopping counter: 2 out of 10.000000
# 38	0.037897
# 38	0.04175	0.399	0.348	0.472
# EarlyStopping counter: 3 out of 10.000000
# 39	0.037661
# 39	0.04171	0.401	0.354	0.466
# Validation loss decreased (0.041732 --> 0.041713).  Saving model ...
# 40	0.036907
# 40	0.04162	0.409	0.373	0.457
# Validation loss decreased (0.041713 --> 0.041624).  Saving model ...
# 41	0.037025
# 41	0.04227	0.401	0.354	0.467
# EarlyStopping counter: 1 out of 10.000000
# 42	0.037086
# 42	0.04144	0.395	0.342	0.472
# Validation loss decreased (0.041624 --> 0.041439).  Saving model ...
# 43	0.037139
# 43	0.04217	0.401	0.353	0.468
# EarlyStopping counter: 1 out of 10.000000
# 44	0.037022
# 44	0.04229	0.410	0.375	0.458
# EarlyStopping counter: 2 out of 10.000000
# 45	0.036951
# 45	0.04256	0.389	0.334	0.467
# EarlyStopping counter: 3 out of 10.000000
# 46	0.036406
# 46	0.04178	0.408	0.364	0.466
# EarlyStopping counter: 4 out of 10.000000
# 47	0.036320
# 47	0.04297	0.407	0.366	0.462
# EarlyStopping counter: 5 out of 10.000000
# 48	0.036269
# 48	0.04248	0.411	0.366	0.471
# EarlyStopping counter: 6 out of 10.000000
# 49	0.036229
# 49	0.04289	0.417	0.381	0.464
# EarlyStopping counter: 7 out of 10.000000
# 50	0.036054
# 50	0.04292	0.422	0.394	0.458
# EarlyStopping counter: 8 out of 10.000000
# 51	0.035503
# 51	0.04227	0.421	0.393	0.456
# EarlyStopping counter: 9 out of 10.000000
# 52	0.035269
# 52	0.04310	0.406	0.361	0.466
# EarlyStopping counter: 10 out of 10.000000
# Early stopping
# 1	0.379	0.398	0.362	0.160	0.375	0.288	0.539
# epoch	loss
# epoch	loss	F1	pre	rec
# 0	2.772823
# 0	19.71480	0.006	0.003	0.527
# Validation loss decreased (inf --> 19.714796).  Saving model ...
# 1	0.863824
# 1	0.77067	0.235	0.175	0.374
# Validation loss decreased (19.714796 --> 0.770666).  Saving model ...
# 2	0.630221
# 2	5.11205	0.052	0.028	0.380
# EarlyStopping counter: 1 out of 10.000000
# 3	0.380377
# 3	0.43091	0.304	0.259	0.369
# Validation loss decreased (0.770666 --> 0.430905).  Saving model ...
# 4	0.215159
# 4	0.28578	0.330	0.282	0.402
# Validation loss decreased (0.430905 --> 0.285784).  Saving model ...
# 5	0.192164
# 5	0.28589	0.206	0.144	0.363
# EarlyStopping counter: 1 out of 10.000000
# 6	0.176850
# 6	0.19637	0.346	0.318	0.382
# Validation loss decreased (0.285784 --> 0.196372).  Saving model ...
# 7	0.106461
# 7	0.13179	0.353	0.312	0.407
# Validation loss decreased (0.196372 --> 0.131789).  Saving model ...
# 8	0.078803
# 8	0.10082	0.369	0.343	0.400
# Validation loss decreased (0.131789 --> 0.100825).  Saving model ...
# 9	0.070643
# 9	0.09503	0.376	0.357	0.398
# Validation loss decreased (0.100825 --> 0.095034).  Saving model ...
# 10	0.062358
# 10	0.07922	0.370	0.342	0.405
# Validation loss decreased (0.095034 --> 0.079219).  Saving model ...
# 11	0.080316
# 11	0.10213	0.324	0.276	0.394
# EarlyStopping counter: 1 out of 10.000000
# 12	0.063640
# 12	0.08066	0.384	0.364	0.407
# EarlyStopping counter: 2 out of 10.000000
# 13	0.056485
# 13	0.06891	0.383	0.361	0.409
# Validation loss decreased (0.079219 --> 0.068911).  Saving model ...
# 14	0.050493
# 14	0.06440	0.389	0.385	0.394
# Validation loss decreased (0.068911 --> 0.064403).  Saving model ...
# 15	0.047610
# 15	0.05840	0.388	0.366	0.415
# Validation loss decreased (0.064403 --> 0.058398).  Saving model ...
# 16	0.044580
# 16	0.05521	0.396	0.386	0.407
# Validation loss decreased (0.058398 --> 0.055210).  Saving model ...
# 17	0.044061
# 17	0.05529	0.396	0.380	0.414
# EarlyStopping counter: 1 out of 10.000000
# 18	0.043553
# 18	0.05463	0.401	0.385	0.421
# Validation loss decreased (0.055210 --> 0.054632).  Saving model ...
# 19	0.042242
# 19	0.05182	0.406	0.400	0.415
# Validation loss decreased (0.054632 --> 0.051818).  Saving model ...
# 20	0.041880
# 20	0.05310	0.402	0.387	0.421
# EarlyStopping counter: 1 out of 10.000000
# 21	0.041818
# 21	0.05166	0.407	0.391	0.425
# Validation loss decreased (0.051818 --> 0.051664).  Saving model ...
# 22	0.041023
# 22	0.05111	0.411	0.408	0.415
# Validation loss decreased (0.051664 --> 0.051113).  Saving model ...
# 23	0.040463
# 23	0.05042	0.409	0.393	0.427
# Validation loss decreased (0.051113 --> 0.050418).  Saving model ...
# 24	0.040455
# 24	0.05070	0.409	0.397	0.424
# EarlyStopping counter: 1 out of 10.000000
# 25	0.039627
# 25	0.05092	0.417	0.415	0.421
# EarlyStopping counter: 2 out of 10.000000
# 26	0.039866
# 26	0.05006	0.419	0.420	0.420
# Validation loss decreased (0.050418 --> 0.050064).  Saving model ...
# 27	0.039610
# 27	0.05024	0.417	0.404	0.432
# EarlyStopping counter: 1 out of 10.000000
# 28	0.039566
# 28	0.05091	0.417	0.411	0.425
# EarlyStopping counter: 2 out of 10.000000
# 29	0.039313
# 29	0.05123	0.416	0.406	0.428
# EarlyStopping counter: 3 out of 10.000000
# 30	0.038863
# 30	0.05089	0.420	0.411	0.430
# EarlyStopping counter: 4 out of 10.000000
# 31	0.038990
# 31	0.05106	0.415	0.404	0.427
# EarlyStopping counter: 5 out of 10.000000
# 32	0.039223
# 32	0.05014	0.416	0.402	0.433
# EarlyStopping counter: 6 out of 10.000000
# 33	0.038752
# 33	0.05172	0.414	0.399	0.431
# EarlyStopping counter: 7 out of 10.000000
# 34	0.038509
# 34	0.05092	0.415	0.410	0.421
# EarlyStopping counter: 8 out of 10.000000
# 35	0.038760
# 35	0.05183	0.418	0.406	0.430
# EarlyStopping counter: 9 out of 10.000000
# 36	0.038342
# 36	0.05099	0.420	0.410	0.431
# EarlyStopping counter: 10 out of 10.000000
# Early stopping
# 2	0.372	0.453	0.316	0.160	0.399	0.335	0.495

# %% [markdown]
# ### 5. Model fitting
#
# The model will be now trained with the optimal number of epochs and all the training data.

# %%
epoch = 0
nepoch = 43
cases = dloaderAll.get_labels()

sampler_list = Sampler(cases, 0, 1, nbatch, partsize=[1, 0, 0])
trainingSampler = sampler_list.batch_ind("train")
total_batch_train = len(trainingSampler)

N_in_1 = len(dloaderAll.get_PSD(cases[0]))
N_in_2 = len(dloaderAll.get_Taxon(cases[0]))
N_in_3 = len(dloaderAll.get_Emb(cases[0]))

DeeProtGO_Euka_NK_BP = DNNModel(res_dir, propOutFile = propOutFile, nbatch = nbatch, N_in_1 = N_in_1, 
                       N_in_2 = N_in_2, N_in_3 = N_in_3, pN1_1 = pPSD1, pN1_2 = pPSD2, 
                       pN2_1 = pEmb1, pN2_2 = pEmb2, pN3_1 = pTaxon1, pN3_2 = pTaxon2,
                       pNO_1 = pHidden1, pNO_2 = pHidden2, thresh = thresh, pDrop = pDrop, 
                       activFunc = activFunc, optimMethod = optimMethod,criterion = criterion, 
                       learning_rate = learning_rate, useGPU = use_GPU)

# %%
while epoch < nepoch:
    train_loss_A = 0
    for it in range(total_batch_train):
        inData1, inData2, inData3, _, _, _, outData = dloaderAll.get_batch(trainingSampler[it])
        lossA, _ = DeeProtGO_Euka_NK_BP.train(outData, inData1, inData2, inData3)
        train_loss_A += lossA
    train_loss_A = train_loss_A/total_batch_train
    msgA = "%d\t%.6f\n" %(epoch, train_loss_A)
    print(msgA)
    epoch += 1
# Out:
# 0	2.201572
#
# 1	0.887377
#
# 2	0.511639
#
# 3	0.442043
#
# 4	0.229409
#
# 5	0.115245
#
# 6	0.085406
#
# 7	0.063761
#
# 8	0.055834
#
# 9	0.051877
#
# 10	0.048662
#
# 11	0.046085
#
# 12	0.044583
#
# 13	0.044209
#
# 14	0.043724
#
# 15	0.043215
#
# 16	0.042643
#
# 17	0.042263
#
# 18	0.042148
#
# 19	0.041647
#
# 20	0.041475
#
# 21	0.041277
#
# 22	0.040742
#
# 23	0.040903
#
# 24	0.040548
#
# 25	0.040663
#
# 26	0.040289
#
# 27	0.039926
#
# 28	0.039969
#
# 29	0.039501
#
# 30	0.040026
#
# 31	0.039340
#
# 32	0.039014
#
# 33	0.038890
#
# 34	0.039034
#
# 35	0.039401
#
# 36	0.038788
#
# 37	0.038794
#
# 38	0.038560
#
# 39	0.038186
#
# 40	0.038308
#
# 41	0.037926
#
# 42	0.037697

# %%
torch.save(DeeProtGO_Euka_NK_BP.net.state_dict(), res_dir + 'DeeProtGO_PSD_Emb_Taxon_Euka_BP_NK.pt')
